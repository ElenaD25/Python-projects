# %%
import pandas as pd
import numpy as np
import datetime

# %%
df = pd.read_csv("C:/Users/Administrator/Downloads/CoffeeShopDataset/CoffeeShop.csv")
df.head()
# Out:
#    transaction_id transaction_date transaction_time  store_id store_location  \
# 0          114301       01-06-2023         11:33:29         3        Astoria
# 1          115405       02-06-2023         11:18:24         3        Astoria
# 2          115478       02-06-2023         12:02:45         3        Astoria
# 3          116288       02-06-2023         19:39:47         3        Astoria
# 4          116714       03-06-2023         12:24:57         3        Astoria
#
#    product_id  transaction_qty  unit_price  Total_Bill product_category  \
# 0          45                1         3.0         3.0              Tea
# 1          45                1         3.0         3.0              Tea
# 2          45                1         3.0         3.0              Tea
# 3          45                1         3.0         3.0              Tea
# 4          45                1         3.0         3.0              Tea
#
# ...

# %%
df.tail()
# Out:
#         transaction_id transaction_date transaction_time  store_id  \
# 149111          129465       14-06-2023         08:34:10         5
# 149112          133523       17-06-2023         09:55:47         8
# 149113          133674       17-06-2023         10:41:11         8
# 149114          133744       17-06-2023         11:18:31         8
# 149115          149043       30-06-2023         11:18:31         8
#
#          store_location  product_id  transaction_qty  unit_price  Total_Bill  \
# 149111  Lower Manhattan          41                4        4.25        17.0
# 149112   Hell's Kitchen           8                8       45.00       360.0
# 149113   Hell's Kitchen           8                8       45.00       360.0
# 149114   Hell's Kitchen           8                8       45.00       360.0
# 149115   Hell's Kitchen           8                8       45.00       360.0
#
#        product_category      product_type product_detail         Size  \
# ...

# %%
df_shape = np.array(df.shape)
print("Our dataframe has " + df_shape[0].astype(str) + " rows and " + df_shape[1].astype(str) + " columns")
# Out:
# Our dataframe has 149116 rows and 18 columns

# %%
df.describe()
# Out:
#        transaction_id       store_id     product_id  transaction_qty  \
# count   149116.000000  149116.000000  149116.000000    149116.000000
# mean     74737.371872       5.342063      47.918607         1.438276
# std      43153.600016       2.074241      17.930020         0.542509
# min          1.000000       3.000000       1.000000         1.000000
# 25%      37335.750000       3.000000      33.000000         1.000000
# 50%      74727.500000       5.000000      47.000000         1.000000
# 75%     112094.250000       8.000000      60.000000         2.000000
# max     149456.000000       8.000000      87.000000         8.000000
#
#           unit_price     Total_Bill           Hour          Month  \
# count  149116.000000  149116.000000  149116.000000  149116.000000
# mean        3.382219       4.686367      11.735790       3.988881
# std         2.658723       4.227099       3.764662       1.673091
# min         0.800000       0.800000       6.000000       1.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  object
#  2   transaction_time  149116 non-null  object
#  3   store_id          149116 non-null  int64
#  4   store_location    149116 non-null  object
#  5   product_id        149116 non-null  int64
#  6   transaction_qty   149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   Total_Bill        149116 non-null  float64
#  9   product_category  149116 non-null  object
#  10  product_type      149116 non-null  object
#  11  product_detail    149116 non-null  object
#  12  Size              149116 non-null  object
#  13  Month Name        149116 non-null  object
#  14  Day Name          149116 non-null  object
#  15  Hour              149116 non-null  int64
# ...

# %%
#identify if there are any null values in the dataset
df.isnull().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# store_id            0
# store_location      0
# product_id          0
# transaction_qty     0
# unit_price          0
# Total_Bill          0
# product_category    0
# product_type        0
# product_detail      0
# Size                0
# Month Name          0
# Day Name            0
# Hour                0
# Month               0
# Day of Week         0
# dtype: int64

# %%
#identify the unique values (it doesn't count the N/A values)
df.nunique()
# Out:
# transaction_id      149116
# transaction_date       181
# transaction_time     25762
# store_id                 3
# store_location           3
# product_id              80
# transaction_qty          6
# unit_price              41
# Total_Bill              75
# product_category         9
# product_type            29
# product_detail          45
# Size                     4
# Month Name               6
# Day Name                 7
# Hour                    15
# Month                    6
# Day of Week              7
# dtype: int64

# %%
df['transaction_id'].duplicated().sum()
# Out:
# 0

# %%
#Convert the transaction_date column
df['transaction_date'] = pd.to_datetime(df['transaction_date'],format='%d-%m-%Y').dt.strftime('%Y-%m-%d')

# %%
df.head()
# Out:
#    transaction_id transaction_date transaction_time  store_id store_location  \
# 0          114301       2023-06-01         11:33:29         3        Astoria
# 1          115405       2023-06-02         11:18:24         3        Astoria
# 2          115478       2023-06-02         12:02:45         3        Astoria
# 3          116288       2023-06-02         19:39:47         3        Astoria
# 4          116714       2023-06-03         12:24:57         3        Astoria
#
#    product_id  transaction_qty  unit_price  Total_Bill product_category  \
# 0          45                1         3.0         3.0              Tea
# 1          45                1         3.0         3.0              Tea
# 2          45                1         3.0         3.0              Tea
# 3          45                1         3.0         3.0              Tea
# 4          45                1         3.0         3.0              Tea
#
# ...

# %%
df['transaction_date']=pd.to_datetime(df['transaction_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  datetime64[ns]
#  2   transaction_time  149116 non-null  object
#  3   store_id          149116 non-null  int64
#  4   store_location    149116 non-null  object
#  5   product_id        149116 non-null  int64
#  6   transaction_qty   149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   Total_Bill        149116 non-null  float64
#  9   product_category  149116 non-null  object
#  10  product_type      149116 non-null  object
#  11  product_detail    149116 non-null  object
#  12  Size              149116 non-null  object
#  13  Month Name        149116 non-null  object
#  14  Day Name          149116 non-null  object
# ...

# %%
df.head()
# Out:
#    transaction_id transaction_date transaction_time  store_id store_location  \
# 0          114301       2023-06-01         11:33:29         3        Astoria
# 1          115405       2023-06-02         11:18:24         3        Astoria
# 2          115478       2023-06-02         12:02:45         3        Astoria
# 3          116288       2023-06-02         19:39:47         3        Astoria
# 4          116714       2023-06-03         12:24:57         3        Astoria
#
#    product_id  transaction_qty  unit_price  Total_Bill product_category  \
# 0          45                1         3.0         3.0              Tea
# 1          45                1         3.0         3.0              Tea
# 2          45                1         3.0         3.0              Tea
# 3          45                1         3.0         3.0              Tea
# 4          45                1         3.0         3.0              Tea
#
# ...

# %%
df.drop(columns=['Month Name','Day Name','Hour','Month','Day of Week','Total_Bill'], axis=1, inplace=True)

# %%
df.rename(columns = {"Size":"size"}, inplace = True)
df.head()
# Out:
#    transaction_id transaction_date transaction_time  store_id store_location  \
# 0          114301       2023-06-01         11:33:29         3        Astoria
# 1          115405       2023-06-02         11:18:24         3        Astoria
# 2          115478       2023-06-02         12:02:45         3        Astoria
# 3          116288       2023-06-02         19:39:47         3        Astoria
# 4          116714       2023-06-03         12:24:57         3        Astoria
#
#    product_id  transaction_qty  unit_price product_category  \
# 0          45                1         3.0              Tea
# 1          45                1         3.0              Tea
# 2          45                1         3.0              Tea
# 3          45                1         3.0              Tea
# 4          45                1         3.0              Tea
#
#         product_type product_detail   size
# 0  Brewed herbal tea     Peppermint  Large
# 1  Brewed herbal tea     Peppermint  Large
# ...

# %%
df['transaction_time'] = pd.to_datetime(df['transaction_time'], format='%I:%M:%S %p')

df['transaction_time'] = df['transaction_time'].dt.time
#df.drop(columns=['time'], axis=1, inplace=True)
df.head()
# Out:
#    transaction_id transaction_date transaction_time  store_id store_location  \
# 0          114301       2023-06-01         11:33:29         3        Astoria
# 1          115405       2023-06-02         11:18:24         3        Astoria
# 2          115478       2023-06-02         12:02:45         3        Astoria
# 3          116288       2023-06-02         19:39:47         3        Astoria
# 4          116714       2023-06-03         12:24:57         3        Astoria
#
#    product_id  transaction_qty  unit_price product_category  \
# 0          45                1         3.0              Tea
# 1          45                1         3.0              Tea
# 2          45                1         3.0              Tea
# 3          45                1         3.0              Tea
# 4          45                1         3.0              Tea
#
#         product_type product_detail   size
# 0  Brewed herbal tea     Peppermint  Large
# 1  Brewed herbal tea     Peppermint  Large
# ...

# %%
df['transaction_time'] = pd.to_datetime(df['transaction_time'], format='%H:%M:%S')
df['hour'] = df['transaction_time'].dt.hour

df['transaction_time'] = pd.to_datetime(df['transaction_time'], format='%H:%M:%S').dt.strftime('%I:%M:%S %p')
df.head()
# Out:
#    transaction_id transaction_date transaction_time  store_id store_location  \
# 0          114301       2023-06-01      11:33:29 AM         3        Astoria
# 1          115405       2023-06-02      11:18:24 AM         3        Astoria
# 2          115478       2023-06-02      12:02:45 PM         3        Astoria
# 3          116288       2023-06-02      07:39:47 PM         3        Astoria
# 4          116714       2023-06-03      12:24:57 PM         3        Astoria
#
#    product_id  transaction_qty  unit_price product_category  \
# 0          45                1         3.0              Tea
# 1          45                1         3.0              Tea
# 2          45                1         3.0              Tea
# 3          45                1         3.0              Tea
# 4          45                1         3.0              Tea
#
#         product_type product_detail   size  hour
# 0  Brewed herbal tea     Peppermint  Large    11
# ...

# %%
df['total'] = df['transaction_qty'] * df['unit_price']

# %%
df['month_name']=df['transaction_date'].dt.strftime('%b-%Y')
df['day_name']=df['transaction_date'].dt.day_name()

# %%
df.head()
# Out:
#    transaction_id transaction_date transaction_time  store_id store_location  \
# 0          114301       2023-06-01      11:33:29 AM         3        Astoria
# 1          115405       2023-06-02      11:18:24 AM         3        Astoria
# 2          115478       2023-06-02      12:02:45 PM         3        Astoria
# 3          116288       2023-06-02      07:39:47 PM         3        Astoria
# 4          116714       2023-06-03      12:24:57 PM         3        Astoria
#
#    product_id  transaction_qty  unit_price product_category  \
# 0          45                1         3.0              Tea
# 1          45                1         3.0              Tea
# 2          45                1         3.0              Tea
# 3          45                1         3.0              Tea
# 4          45                1         3.0              Tea
#
#         product_type product_detail   size  hour  total month_name  day_name
# ...

# %%
df.to_csv(r'\\Coffee_Shop_cleaned.csv', index=False)
